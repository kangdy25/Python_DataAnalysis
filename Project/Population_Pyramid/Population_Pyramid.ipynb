# %% [markdown]
# # 인구 피라미드

# %% [markdown]
# ### 남자 데이터 정의

# %%
import pandas as pd
file_name = '202101_202104_연령별인구현황_월간.xlsx'
df_m = pd.read_excel(file_name, skiprows = 3, index_col='행정기관', usecols='B, E:Y')
df_m.head(3)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       851,013  1,171,455  1,207,725  1,265,942  1,689,271  1,877,164
# 서울특별시    137,526    180,037    191,388    208,366    299,320    405,542
# 부산광역시     49,265     69,142     67,557     72,748    105,536    118,001
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,636,673  1,895,766  1,997,717  2,212,787  ...  2,118,559
# 서울특별시      362,630    373,183    360,752    394,559  ...    359,251
# 부산광역시       98,395    115,223    123,575    133,295  ...    137,210
#
#             60~64세     65~69세   70~74세   75~79세   80~84세   85~89세  90~94세  \
# 행정기관
# 전국       1,966,428  1,357,173  978,723  691,404  433,404  180,123  47,331
# 서울특별시      340,731    249,472  186,664  134,700   78,461   30,911   8,968
# 부산광역시      143,173    109,702   78,659   53,843   30,829   11,225   2,737
#
#          95~99세 100세 이상
# 행정기관
# 전국       10,351   5,423
# 서울특별시     2,364   1,827
# 부산광역시       607     421
#
# [3 rows x 21 columns]

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',', '').astype(int) # 1,195,951 -> 1195951 (정수형)

# %%
df_m.iloc[0]
# Out:
# 0~4세        851013
# 5~9세       1171455
# 10~14세     1207725
# 15~19세     1265942
# 20~24세     1689271
# 25~29세     1877164
# 30~34세     1636673
# 35~39세     1895766
# 40~44세     1997717
# 45~49세     2212787
# 50~54세     2244080
# 55~59세     2118559
# 60~64세     1966428
# 65~69세     1357173
# 70~74세      978723
# 75~79세      691404
# 80~84세      433404
# 85~89세      180123
# 90~94세       47331
# 95~99세       10351
# 100세 이상       5423
# Name: 전국  , dtype: object

# %% [markdown]
# ### 여자 데이터 정의

# %%
df_w = pd.read_excel(file_name, skiprows = 3, index_col='행정기관', usecols='B, AB:AV')
df_w.head(3)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       808,092  1,113,684  1,137,280  1,173,441  1,550,314  1,675,734
# 서울특별시    129,666    171,268    180,963    198,193    327,336    422,846
# 부산광역시     46,925     65,484     63,761     67,494     99,034    106,742
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,510,845  1,813,130  1,930,352  2,145,079  ...  2,083,448
# 서울특별시      363,974    371,819    367,246    402,114  ...    374,655
# 부산광역시       92,477    111,721    119,819    133,502  ...    147,881
#
#           60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국       2,011,027  1,459,921  1,116,830  920,726  715,945  410,914  158,505
# 서울특별시      376,199    283,696    220,311  164,440  110,997   59,794   24,823
# 부산광역시      157,723    123,790     92,409   68,970   49,025   25,525    9,588
#
#         95~99세.1 100세 이상.1
# 행정기관
# 전국        38,843    16,697
# 서울특별시      6,874     5,026
# 부산광역시      2,305     1,480
#
# [3 rows x 21 columns]

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns # 컬럼 명 통일
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',', '').astype(int) # 1,195,951 -> 1195951 (정수형)
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          808092  1113684  1137280  1173441  1550314  1675734  1510845
# 서울특별시      129,666  171,268  180,963  198,193  327,336  422,846  363,974
# 부산광역시       46,925   65,484   63,761   67,494   99,034  106,742   92,477
# 대구광역시       35,639   50,682   51,552   55,923   75,169   74,364   62,257
# 인천광역시       46,310   64,217   65,618   67,229   89,368  102,404   89,283
# 광주광역시       23,610   34,163   36,334   39,126   51,088   48,765   39,899
# 대전광역시       22,973   32,325   33,990   36,465   50,256   50,639   42,332
# 울산광역시       19,930   27,592   26,981   26,174   31,078   32,126   30,609
# 세종특별자치시     10,183   12,857   12,194    9,272    8,150   10,385   13,307
# 경기도        235,265  321,520  323,638  321,571  410,443  446,198  414,826
# 강원도         21,947   29,377   31,315   34,347   41,208   37,233   34,654
# 충청북도        25,332   34,499   35,325   36,180   44,650   43,376   40,368
# 충청남도        35,236   48,366   48,796   48,451   54,992   53,626   54,383
# 전라북도        24,908   37,204   40,385   43,731   51,722   45,386   39,626
# 전라남도        27,056   37,288   38,958   41,442   47,113   41,231   37,907
# 경상북도        38,448   52,642   52,476   54,668   63,551   59,313   57,908
# 경상남도        52,637   77,079   77,797   76,662   85,751   81,582   79,818
# 제주특별자치도     12,027   17,121   17,197   16,513   19,405   19,518   17,217
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         1813130  1930352  2145079  ...  2083448  2011027  1459921  1116830
# 서울특별시      371,819  367,246  402,114  ...  374,655  376,199  283,696  220,311
# 부산광역시      111,721  119,819  133,502  ...  147,881  157,723  123,790   92,409
# 대구광역시       78,336   88,932  104,973  ...  105,841   98,049   73,914   55,120
# 인천광역시      106,324  112,479  123,875  ...  126,297  113,214   74,080   54,344
# 광주광역시       50,870   57,295   63,882  ...   55,286   50,808   35,302   29,496
# 대전광역시       50,309   55,593   63,063  ...   57,521   54,877   38,117   27,693
# 울산광역시       40,264   43,308   48,675  ...   49,191   43,871   28,902   18,491
# 세종특별자치시     18,178   18,448   15,530  ...    9,829    9,125    6,288    4,332
# 경기도        509,447  542,863  588,377  ...  522,897  465,289  313,243  232,195
# 강원도         44,035   50,125   58,754  ...   66,176   71,146   51,174   37,334
# 충청북도        50,779   54,074   61,848  ...   65,289   65,247   47,247   33,729
# 충청남도        69,008   73,323   79,732  ...   79,714   80,189   60,772   49,224
# 전라북도        51,559   59,199   70,523  ...   71,588   73,590   56,586   50,745
# 전라남도        49,829   55,912   64,872  ...   73,972   76,852   59,090   54,736
# 경상북도        77,257   84,114   98,785  ...  112,685  115,617   91,857   69,243
# 경상남도       109,894  122,051  137,779  ...  138,852  135,488   99,153   73,852
# 제주특별자치도     23,501   25,571   28,795  ...   25,774   23,743   16,710   13,576
#
#             75~79세   80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국          920726   715945  410914  158505  38843   16697
# 서울특별시      164,440  110,997  59,794  24,823  6,874   5,026
# 부산광역시       68,970   49,025  25,525   9,588  2,305   1,480
# 대구광역시       43,758   32,962  17,752   6,104  1,355     566
# 인천광역시       42,481   32,166  18,929   7,754  1,997     717
# 광주광역시       22,748   16,543   9,250   3,755    905     371
# 대전광역시       22,189   16,538   9,636   3,673    865     284
# 울산광역시       13,227    9,716   5,552   2,031    524     140
# 세종특별자치시      3,477    2,808   1,920     784    164      40
# 경기도        187,695  142,008  81,086  32,219  8,046   3,200
# 강원도         37,406   30,277  16,444   7,095  1,707     600
# 충청북도        32,562   26,997  16,194   5,873  1,343     409
# 충청남도        44,676   39,786  25,334   8,942  2,141     718
# 전라북도        44,541   37,447  23,542   8,837  1,912     687
# 전라남도        53,548   48,110  27,309  10,517  2,524     761
# 경상북도        64,704   57,202  34,012  12,313  2,792     785
# 경상남도        62,950   53,810  32,201  11,636  2,478     656
# 제주특별자치도     11,354    9,553   6,434   2,561    911     257
#
# [18 rows x 21 columns]

# %% [markdown]
# ## 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용시 마이너스 글자 깨지는 현상 해결b

# %%
plt.figure(figsize = (10, 7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) # 단위: 천 명
plt.barh(df_w.columns, df_w.iloc[0] // 1000) # 단위: 천 명

plt.title('2021 대한민국 인구 피라미드')
plt.savefig('2021_인구피라미드.png', dpi=1000)
plt.show()
